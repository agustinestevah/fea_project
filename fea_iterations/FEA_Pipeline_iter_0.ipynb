# %%
import pandas as pd
import sys
import pickle
import importlib
import os
import numpy as np
import scrapbook as sb
from sentence_transformers import SentenceTransformer

# Ensure project root is on sys.path (required for papermill fresh kernels)
current_dir = os.getcwd()
if current_dir not in sys.path:
    sys.path.insert(0, current_dir)

import free_entailments_algorithm_utils as fea

# %%
iteration_number = 1
input_csv_path = "labeled_pairs/Results_DS_BtoS_iteration_0.csv"
df_clause_path = None
embedding_cache_path = None
test = True
remaining_llm_calls_path = None
unlabeled_pairs_path = None
sent_frac = 0.5
budget = 0.00

# %%
# Parameters
iteration_number = 0
input_csv_path = "labeled_pairs/Results_DS_BtoS_iteration_0.csv"
df_clause_path = "fea_iterations\\loop_data/df_clause.pkl"
embedding_cache_path = "fea_iterations\\loop_data/embedding_cache.pkl"
test = False
remaining_llm_calls_path = None
unlabeled_pairs_path = None
sent_frac = 0.5
budget = 1.0

# %%
pipeline_data = fea.load_pipeline_data(
    df_clause_path=df_clause_path,
    embedding_cache_path=embedding_cache_path,
    test=test,
    remaining_llm_calls_path=remaining_llm_calls_path,
    unlabeled_pairs_path=unlabeled_pairs_path,
    iteration_number=iteration_number,
)

df_clause = pipeline_data['df_clause']
embedding_cache_finetuned = pipeline_data['embedding_cache']
remaining_llm_calls = pipeline_data['remaining_llm_calls']
unlabeled_pairs = pipeline_data['unlabeled_pairs']
# Out:
# ================================================================================
# PARAMETER VALUES AFTER PAPERMILL INJECTION:
# ================================================================================
# iteration_number = 0
# test = False
# remaining_llm_calls_path = None
# df_clause_path = fea_iterations\loop_data/df_clause.pkl
# ================================================================================
#
# ✓ Loaded df_clause: 38635 rows
# ✓ Loaded embedding cache: 38635 embeddings
# Production mode: no pre-built unlabeled_pairs pool.
#   Candidates will be generated after tau is learned each iteration.
# ✓ All data loaded from pickle files

# %% [markdown]
# # Task 1: Seting up dataframes and Running FEA

# %%
df_llm_original = pd.read_csv(input_csv_path)

# If 'verdict' column already exists (e.g. from process_llm_results_bidirectional),
# use it directly instead of recomputing via add_verdict (which only sees one-way
# conclusions and would overwrite correct bidirectional verdicts).
if 'verdict' in df_llm_original.columns and df_llm_original['verdict'].notna().any():
    df_llm = df_llm_original
    print(f"Using existing 'verdict' column ({(df_llm['verdict']=='YES').sum()} YES, {(df_llm['verdict']=='NO').sum()} NO)")
else:
    df_llm = fea.add_verdict(
        df_llm_original,
        id1_col='sentence_id_1',
        id2_col='sentence_id_2',
        conclusion_col='llm_conclusion_12',
        positive_label='YES'
    )

if test:
    df_llm_remaining = fea.add_verdict(
        remaining_llm_calls,
        id1_col='sentence_id_1',
        id2_col='sentence_id_2',
        conclusion_col='llm_conclusion_12',
        positive_label='YES'
    )
# Out:
# Using existing 'verdict' column (59714 YES, 159690 NO)

# %%
df_labeled = fea.merge_pairwise_texts(
    df1 = df_clause,
    df2 = df_llm,
    df1_cols = ['sentence_id', 'sentence'],
    df2_cols = ['sentence_id_1', 'sentence_id_2', 'verdict']
)
df_labeled.head()
# Out:
# Filtered 48 pairs (kept 219356).
#             id1           id2  \
# 0     B0497006p  S0018448004p
# 1  S0018448004p     B0497006p
# 2     B0775008p  S0020882004p
# 3  S0020882004p     B0775008p
# 4     B0205007p  S0023772003p
#
#                                                text1  \
# 0  The enjoyment of property and freedom is conti...
# 1   This stance reflects a commitment to due process
# 2  The notion that kings are above the law and no...
# 3  This expectation undermines the principle of a...
# 4  All magistrates, including kings, are accounta...
#
#                                                text2 verdict
# 0   This stance reflects a commitment to due process      NO
# 1  The enjoyment of property and freedom is conti...      NO
# 2  This expectation undermines the principle of a...      NO
# 3  The notion that kings are above the law and no...      NO
# 4  The actions taken during this significant occa...      NO

# %%
import gc

if test:
    df_predict = fea.merge_pairwise_texts(
        df1 = df_clause,
        df2 = df_llm_remaining,
        df1_cols = ['sentence_id', 'sentence'],
        df2_cols = ['sentence_id_1', 'sentence_id_2']
    )
else:
    # Production: no pre-built candidate pool.
    # Candidates are generated AFTER tau_n is learned each iteration (see FEA cell).
    df_predict = pd.DataFrame(columns=['id1', 'id2'])
    unlabeled_pairs = None   # keep defined — passed to finalize_pipeline_iteration
    print("Production mode: df_predict empty — candidates generated after tau.")

df_predict.head()
# Out:
# Production mode: df_predict empty — candidates generated after tau.
# Empty DataFrame
# Columns: [id1, id2]
# Index: []

# %% [markdown]
# ## Embedding All Sentences

# %%
## Patches an error later on with kwargs
import transformers.utils.hub
import transformers.tokenization_utils_base

def _safe_list_templates(*args, **kwargs):
    return []

transformers.utils.hub.list_repo_templates = _safe_list_templates
print(" - Patched transformers.utils.hub")

# The library had already imported the broken function here, so we must update it.
transformers.tokenization_utils_base.list_repo_templates = _safe_list_templates
print(" - Patched transformers.tokenization_utils_base")

print("\nSUCCESS: The 404 error is now blocked.")
# Out:
#  - Patched transformers.utils.hub
#  - Patched transformers.tokenization_utils_base
#
# SUCCESS: The 404 error is now blocked.

# %% [markdown]
# ## Test and Validation Subsamples

# %%
# Keep only entailed pairs from sent
df_obs_ent = df_labeled.loc[df_labeled['verdict'] == 'YES']
df_obs_ent.head()
# Out:
#                  id1            id2  \
# 101084     B0120007p   S0024320005p
# 101085  S0024320005p      B0120007p
# 101090     B0659007p   S0000893006p
# 101091  S0000893006p      B0659007p
# 101100    B1086002sc  S0017273003sc
#
#                                                     text1  \
# 101084  The desire for absolute power contradicts the ...
# 101085           This concentration of power is dangerous
# 101090  The community retains a greater power than tha...
# 101091  The people of England have the right to resist...
# 101100          threatens the stability of a Commonwealth
#
#                                                     text2 verdict
# 101084           This concentration of power is dangerous     YES
# 101085  The desire for absolute power contradicts the ...     YES
# 101090  The people of England have the right to resist...     YES
# 101091  The community retains a greater power than tha...     YES
# 101100                      it threatens social stability     YES

# %%
# --- Memory-efficient path for large candidate pools ---
# Uses vectorised alpha + equiv_map lookups instead of storing
# Python list objects in every row (saves ~8 GB at 75M rows).
LARGE_THRESHOLD = 5_000_000

if not test:
    # Production: candidates generated AFTER tau — nothing to build here.
    df_candidates = None
    equiv_map = None
    print("Production mode: skipping df_candidates (generated fresh after tau)")
elif len(df_predict) > LARGE_THRESHOLD:
    print(f"Using memory-efficient path ({len(df_predict):,} candidate rows)")
    df_candidates, df_crossed, equiv_map = fea.prepare_candidates_efficient(
        df_obs_ent=df_obs_ent,
        df_predict=df_predict,
        df_clause=df_clause,
    )
else:
    # Original path (fine for small DataFrames)
    df_candidates = fea.add_equivalents_from_pairs(
        df3=df_obs_ent,
        df4=df_predict,
        df3_cols=["id1", "id2"],
        df4_cols=["id1", "id2"],
        new_cols=("equivalents1", "equivalents2"),
        include_self=False,
    )
    df_candidates = fea.add_alpha_weight_column(
        df = df_candidates,
        list_col1 = 'equivalents1',
        list_col2 = 'equivalents2',
        new_col = "alpha"
    )
    equiv_map = None
# Out:
# Production mode: skipping df_candidates (generated fresh after tau)

# %%
df_labeled = fea.add_equivalents_from_pairs(
    df3=df_obs_ent,
    df4=df_labeled,
    df3_cols=["id1", "id2"],
    df4_cols=["id1", "id2"],
    new_cols=("equivalents1", "equivalents2"),
    include_self=False,  # keep the ID itself in the list
)

df_labeled = fea.add_alpha_weight_column(
    df = df_labeled,
    list_col1 = 'equivalents1',
    list_col2 = 'equivalents2',
    new_col = "alpha"
)

# %% [markdown]
# ## Equivalence Classes

# %%
# Only compute crossed pairs here if we used the original (small) path above.
# The efficient path already produced df_crossed.
# Production: no df_candidates → no df_crossed needed.
if not test:
    df_crossed = None
    print("Production mode: skipping df_crossed (no pre-tau candidates)")
elif equiv_map is None:
    df_crossed = fea.build_equiv_pair_candidates(
        df = df_candidates,
        id1_col = "id1",
        id2_col = "id2",
        equiv1_col = "equivalents1",
        equiv2_col = "equivalents2",
    )
    df_crossed = fea.merge_pairwise_texts(
        df1 = df_clause,
        df2 = df_crossed,
        df1_cols = ['sentence_id', 'sentence'],
        df2_cols = ['id1', 'id2']
    )

if df_crossed is not None:
    df_crossed.head()
# Out:
# Production mode: skipping df_crossed (no pre-tau candidates)

# %%
df_labeled_crossed = fea.build_equiv_pair_candidates(
    df = df_labeled,
    id1_col = "id1",
    id2_col = "id2",
    equiv1_col = "equivalents1",
    equiv2_col = "equivalents2",
)

# Retrieve clause sentences
df_labeled_crossed = fea.merge_pairwise_texts(
    df1 = df_clause,
    df2 = df_labeled_crossed,
    df1_cols = ['sentence_id', 'sentence'],
    df2_cols = ['id1', 'id2']
)

df_labeled_crossed.head()
# Out:
# Filtered 186414 pairs (kept 9035540).
#             id1        id2                                              text1  \
# 0  S0018448004p  B0026006p   This stance reflects a commitment to due process
# 1  S0020882004p  B0205005p  This expectation undermines the principle of a...
# 2  S0020882004p  B0213004p  This expectation undermines the principle of a...
# 3  S0020882004p  B0217007p  This expectation undermines the principle of a...
# 4  S0020882004p  B0223002p  This expectation undermines the principle of a...
#
#                                                text2  verdict
# 0  The enjoyment of property and freedom is conti...      NaN
# 1  The law is what defines the king's authority a...      NaN
# 2  True governance requires that the king's power...      NaN
# 3  Rulers are expected to govern justly and in ac...      NaN
# 4  Limiting the authority of a King is essential ...      NaN

# %% [markdown]
# ## Pre-compute cosine similarities & run FEA

# %%
# Pre-compute all cosine similarities HERE (Pipeline) so FreeEntailmentAlgorithm
# doesn't have to reload the embedding cache or redo this work.

print("Pre-computing cosine similarities in Pipeline...")

# 1. df_candidates → new_cos_sim_score
if df_candidates is None:
    print(f"  ✓ df_candidates: skipped (production mode — no pre-tau candidates)")
elif 'cosine_sim' in df_candidates.columns and 'new_cos_sim_score' not in df_candidates.columns:
    df_candidates = df_candidates.rename(columns={'cosine_sim': 'new_cos_sim_score'})
    print(f"  ✓ df_candidates: renamed cosine_sim → new_cos_sim_score ({len(df_candidates):,} rows)")
elif 'new_cos_sim_score' not in df_candidates.columns:
    df_candidates = fea.generate_new_bert_results(
        df_candidates,
        text_col1='text1',
        text_col2='text2',
        model_path="./fine_tuned_bi_model",
        new_col="new_cos_sim_score",
        embedding_cache=embedding_cache_finetuned,
        id_col1='id1',
        id_col2='id2'
    )
    print(f"  ✓ df_candidates: new_cos_sim_score computed ({len(df_candidates):,} rows)")
else:
    print(f"  ✓ df_candidates: new_cos_sim_score already present ({len(df_candidates):,} rows)")

# 2. df_labeled → new_cos_sim_score
if 'new_cos_sim_score' not in df_labeled.columns:
    df_labeled = fea.generate_new_bert_results(
        df_labeled,
        text_col1='text1',
        text_col2='text2',
        model_path="./fine_tuned_bi_model",
        new_col="new_cos_sim_score",
        embedding_cache=embedding_cache_finetuned,
        id_col1='id1',
        id_col2='id2'
    )
    print(f"  ✓ df_labeled: new_cos_sim_score computed ({len(df_labeled)} rows)")
else:
    print(f"  ✓ df_labeled: new_cos_sim_score already present ({len(df_labeled)} rows)")

# 3. df_crossed → cosine_sim
if df_crossed is None:
    print(f"  ✓ df_crossed: skipped (production mode)")
elif 'cosine_sim' not in df_crossed.columns:
    df_crossed = fea.add_cosine_similarity_from_text(
        df_crossed,
        text_col1="text1",
        text_col2="text2",
        model_name="./fine_tuned_bi_model",
        batch_size=128,
        show_progress_bar=False,
        embedding_cache=embedding_cache_finetuned,
        id_col1='id1',
        id_col2='id2'
    )
    print(f"  ✓ df_crossed: cosine_sim computed ({len(df_crossed):,} rows)")
else:
    print(f"  ✓ df_crossed: cosine_sim already present ({len(df_crossed):,} rows)")

# 4. df_labeled_crossed → cosine_sim
if 'cosine_sim' not in df_labeled_crossed.columns:
    df_labeled_crossed = fea.add_cosine_similarity_from_text(
        df_labeled_crossed,
        text_col1="text1",
        text_col2="text2",
        model_name="./fine_tuned_bi_model",
        batch_size=128,
        show_progress_bar=False,
        embedding_cache=embedding_cache_finetuned,
        id_col1='id1',
        id_col2='id2'
    )
    print(f"  ✓ df_labeled_crossed: cosine_sim computed ({len(df_labeled_crossed)} rows)")
else:
    print(f"  ✓ df_labeled_crossed: cosine_sim already present ({len(df_labeled_crossed)} rows)")

print("✓ All cosine similarities ready")
# Out:
# Pre-computing cosine similarities in Pipeline...
#   ✓ df_candidates: skipped (production mode — no pre-tau candidates)
# Using pre-computed embeddings from cache...
#   ✓ df_labeled: new_cos_sim_score computed (219356 rows)
#   ✓ df_crossed: skipped (production mode)
# Using chunked cosine-similarity path (9,035,540 rows)...
#   cosine-sim chunk 10/19 done
#   cosine-sim chunk 19/19 done
#   ✓ df_labeled_crossed: cosine_sim computed (9035540 rows)
# ✓ All cosine similarities ready

# %%
import gc, os, pickle, json as _json

temp_dir = "fea_iterations/temp_data"
os.makedirs(temp_dir, exist_ok=True)

n_obs  = len(df_obs_ent)

if n_obs == 0:
    # No entailed pairs — cannot train a model
    print(f"⚠ Skipping FreeEntailmentAlgorithm (0 entailed pairs in df_obs_ent)")
    df_final = pd.DataFrame(
        columns=['id1', 'id2', 'text1', 'text2', 'entailment_probability'])
    fig_html = "<p>No data for this iteration</p>"
else:
    # 1. Pickle data for FreeEntailmentAlgorithm subprocess.
    #    In production: df_candidates and df_crossed are None — skip them entirely.
    if df_candidates is not None:
        df_candidates.to_pickle(f"{temp_dir}/df_candidates.pkl")
        print(f"  Pickled df_candidates: {len(df_candidates):,} rows, cols={list(df_candidates.columns)}")
    if df_crossed is not None:
        df_crossed.to_pickle(f"{temp_dir}/df_crossed.pkl")
        print(f"  Pickled df_crossed: {len(df_crossed):,} rows")
    df_labeled.to_pickle(f"{temp_dir}/df_labeled.pkl")
    df_labeled_crossed.to_pickle(f"{temp_dir}/df_labeled_crossed.pkl")
    df_obs_ent.to_pickle(f"{temp_dir}/df_obs_ent.pkl")
    df_clause.to_pickle(f"{temp_dir}/df_clause.pkl")

    # 2. Free large DataFrames BEFORE spawning FreeEntailmentAlgorithm.
    #    papermill runs a NEW kernel — keeping them doubles peak RAM.
    try: del df_candidates
    except NameError: pass
    try: del df_predict
    except NameError: pass
    try: del df_crossed
    except NameError: pass
    try: del df_labeled_crossed
    except NameError: pass
    try: del df_obs_ent
    except NameError: pass
    try: del equiv_map
    except NameError: pass
    gc.collect()
    print("  ✓ Freed large DataFrames before FreeEntailmentAlgorithm subprocess")

    # 3. Execute FreeEntailmentAlgorithm.
    #    production_mode tells FEA to skip all df_candidates/df_crossed work
    #    and only train the model + save artifacts.
    _df_final_from_fea, fig_html = fea.run_fea_papermill(
        iteration_number=iteration_number,
        temp_dir=temp_dir,
        data_on_disk=True,
        production_mode=(not test),
    )
    print(f"  FreeEntailmentAlgorithm done: {len(_df_final_from_fea)} rows in df_final_fea")

    if not test:
        # ── PRODUCTION ──────────────────────────────────────────────────────────
        # FEA trained a model on df_labeled and saved artifacts.
        # Now generate valid pairs with P(entailment) >= tau using the fresh
        # model — same logic as round_0_pairs Step 10.
        _model_info_path = os.path.join(temp_dir, "model_info.json")
        _pipeline_path   = os.path.join(temp_dir, "best_pipeline.pkl")
        with open(_model_info_path) as _f:
            _model_info = _json.load(_f)
        with open(_pipeline_path, 'rb') as _f:
            _best_pipeline = pickle.load(_f)

        tau_current        = float(_model_info['tau'])
        _features          = _model_info.get('features', ['cos_sim_neighbor_score'])
        model_feature_name = _features[0]

        print(f"\n  Production: generating candidates")
        print(f"    tau={tau_current:.4f}  (F2-optimal on entailment_probability)")
        print(f"    model: {_model_info.get('best_model', '?')}  features={_features}")
        print(f"    all thresholds: acc={_model_info.get('best_tau_accuracy','?')}, "
              f"f1={_model_info.get('best_tau_f1','?')}, "
              f"recall={_model_info.get('best_tau_recall','?')}")

        # Split df_clause into premises (sentence_id ends with 'p') and
        # conclusions (sentence_id ends with 'sc').
        _sids    = df_clause['sentence_id'].astype(str)
        df_p_now  = df_clause[_sids.str.endswith('p')].copy()
        df_sc_now = df_clause[_sids.str.endswith('sc')].copy()
        print(f"    df_p_now: {len(df_p_now):,} rows, df_sc_now: {len(df_sc_now):,} rows")

        # Generate valid pairs with P(ent) >= tau_current.
        # Model scoring is inline inside generate_valid_pairs — only surviving
        # pairs are ever accumulated, keeping peak memory bounded.
        # top_k_bs caps BS pairs per group scan as safety valve against OOM.
        df_post_tau = fea.generate_valid_pairs(
            df_p_now, df_sc_now,
            id_col='sentence_id',
            text_col='sentence',
            embedding_cache=embedding_cache_finetuned,
            threshold_bb=0,
            threshold_bs=0,
            batch_size=64,
            top_k_bs=2_000_000,
            exclude_labeled_csv="labeled_pairs/llm_labeled_pairs.csv",
            model_pipeline=_best_pipeline,
            model_tau=tau_current,
            model_feature_name=model_feature_name,
        )
        print(f"  Post-tau pairs: {len(df_post_tau):,}")
        del df_p_now, df_sc_now
        gc.collect()

        # Add entailment_probability by rescoring with the same model.
        # Pass as numpy array to avoid sklearn feature-name warnings.
        if len(df_post_tau) > 0:
            _X = df_post_tau[['cosine_sim']].values   # shape (n, 1)
            df_post_tau = df_post_tau.copy()
            df_post_tau['entailment_probability'] = _best_pipeline.predict_proba(_X)[:, 1]
            del _X
        else:
            df_post_tau['entailment_probability'] = pd.Series(dtype='float64')

        # Add text columns (needed by format_df_to_llm downstream).
        _lut = dict(zip(df_clause['sentence_id'].astype(str), df_clause['sentence']))
        df_post_tau['text1'] = df_post_tau['id1'].astype(str).map(_lut)
        df_post_tau['text2'] = df_post_tau['id2'].astype(str).map(_lut)
        del _best_pipeline, _lut
        gc.collect()

        df_final = df_post_tau[
            ['id1', 'id2', 'text1', 'text2', 'entailment_probability']
        ].reset_index(drop=True)
        print(f"  ✓ df_final (production post-tau): {len(df_final)} rows")
        del df_post_tau
        gc.collect()
    else:
        # ── TEST MODE ──────────────────────────────────────────────────────────
        # Use what FEA produced directly (scored from df_candidates).
        df_final = _df_final_from_fea

    del _df_final_from_fea
    gc.collect()

print(f"✓ df_final: {len(df_final)} rows")
# Out:
#   ✓ Freed large DataFrames before FreeEntailmentAlgorithm subprocess
# Executing FreeEntailmentAlgorithm.ipynb for iteration 0...
# Executing:   0%|          | 0/34 [00:00<?, ?cell/s]
# ✓ Retrieved outputs:
#   - df_final: 0 rows
#   - fig_html: HTML plot (15777 chars)
#   FreeEntailmentAlgorithm done: 0 rows in df_final_fea
#
#   Production: generating candidates
#     tau=0.4837  (F2-optimal on entailment_probability)
#     model: logistic  features=['cos_sim_neighbor_score']
#     all thresholds: acc=0.7065019991396607, f1=0.5559762918213179, recall=0.0010087444289355212
#     df_p_now: 29,635 rows, df_sc_now: 9,000 rows
#   Model-based inline filtering ACTIVE  (tau=0.4837, feature='cos_sim_neighbor_score')
#
# === Generating filtered premise-premise pairs ===
#     [Premises] Scanning 45,730,266 B-B candidates in batches of 64...
#     [Premises] Found 1,998,802 B-B pairs above threshold 0.0000 & model tau 0.4837
#     [Premises] Scanning 191,959,044 B-S candidates  (book batch=64, speech chunk=2048)...
#     [Premises] Found 506,091 B-S pairs above threshold 0.0000 & model tau 0.4837
# === Generating filtered conclusion-conclusion pairs ===
#     [Conclusions] Scanning 3,151,305 B-B candidates in batches of 64...
#     [Conclusions] Found 120,229 B-B pairs above threshold 0.0000 & model tau 0.4837
#     [Conclusions] Scanning 16,293,879 B-S candidates  (book batch=64, speech chunk=2048)...
#     [Conclusions] Found 87,122 B-S pairs above threshold 0.0000 & model tau 0.4837
# === SUMMARY (threshold-filtered) ===
# Book-Book pairs:    2,119,031
# Book-Speech pairs:  593,213
# Total pairs:        2,712,244
# Filtered out 79,730 already-labeled pairs (kept 2,632,514 of 2,712,244)
#   Post-tau pairs: 2,632,514
#   ✓ df_final (production post-tau): 2632514 rows
# ✓ df_final: 2632514 rows

# %%
df_final.head()
# Out:
#          id1        id2                                              text1  \
# 0  B0001001p  B0001002p  Proponents of divine right deny mankind's natu...
# 1  B0001001p  B0001003p  Proponents of divine right deny mankind's natu...
# 2  B0001001p  B0001004p  Proponents of divine right deny mankind's natu...
# 3  B0001001p  B0001007p  Proponents of divine right deny mankind's natu...
# 4  B0001001p  B0001008p  Proponents of divine right deny mankind's natu...
#
#                                                text2  entailment_probability
# 0  Proponents of divine right assert that all men...                0.548081
# 1  Proponents of divine right assert that no indi...                0.628463
# 2  The doctrine of divine right strips individual...                0.688080
# 3  The claim of divine right undermines the very ...                0.572901
# 4  The claim of divine right undermines the natur...                0.660189

# %% [markdown]
# # Task 2: Cleaning LLM Calls

# %%
# Cap at 100k pairs max — send ALL pairs above threshold (no random subsampling)
MAX_LLM_PAIRS = 10

df_final = df_final.reset_index(drop=True)

if len(df_final) > MAX_LLM_PAIRS:
    df_to_llm = df_final.sample(n=MAX_LLM_PAIRS, random_state=42)
    print(f"Capped df_to_llm at {MAX_LLM_PAIRS:,} (from {len(df_final):,} above threshold)")
else:
    df_to_llm = df_final.copy()
    print(f"Sending all {len(df_to_llm):,} pairs above threshold to LLM")
# Out:
# Capped df_to_llm at 10 (from 2,632,514 above threshold)

# %%
df_to_llm = fea.format_df_to_llm(df_to_llm, df_clause=df_clause, id_col='sentence_id', text_col='sentence')
df_to_llm.head()
# Out:
#         sentence_id_2 sentence_id_1  \
# 55984       B0088003p     B0023006p
# 565203      B0165004p     B0130002p
# 1193766     B1220001p     B0258005p
# 1979147    B0217001sc    B0125001sc
# 461390      B0311001p     B0115002p
#
#                                            sentence_text_2 argument_id_2  \
# 55984    If a people's rights are contingent upon the w...         B0088
# 565203   Kings were often appointed under conditions th...         B0165
# 1193766  The existence of a republic is indeed dependen...         B1220
# 1979147  Rulership legitimacy does not rely on the cons...         B0217
# 461390   A king cannot unilaterally impose laws without...         B0311
#
#                                            sentence_text_1 argument_id_1  \
# 55984    The act of consenting to join a community sign...         B0023
# 565203   True consent and election require an explicit ...         B0130
# 1193766  Nations have consistently exercised the right ...         B0258
# 1979147  Ruler authority does not depend on the consent...         B0125
# 461390   The essence of rightful governance is rooted i...         B0115
#
#             score
# 55984    0.550663
# 565203   0.658178
# 1193766  0.662379
# 1979147  0.818440
# 461390   0.520953

# %%
df_to_llm.shape
# Out:
# (10, 7)

# %% [markdown]
# # Next loop:

# %%
# Reload unlabeled_pairs from pickle if in production mode.
# It was freed earlier to save memory while FreeEntailmentAlgorithm ran.
if not test and unlabeled_pairs_path:
    import gc
    unlabeled_pairs = pd.read_pickle(unlabeled_pairs_path)
    print(f"Reloaded unlabeled_pairs: {len(unlabeled_pairs):,} rows")
    gc.collect()

result = fea.finalize_pipeline_iteration(
    test=test,
    df_to_llm=df_to_llm,
    iteration_number=iteration_number,
    remaining_llm_calls=remaining_llm_calls,
    remaining_llm_calls_path=remaining_llm_calls_path,
    unlabeled_pairs=unlabeled_pairs,
    unlabeled_pairs_path=unlabeled_pairs_path,
)

remaining_llm_calls = result['remaining_llm_calls']
unlabeled_pairs = result['unlabeled_pairs']
# Out:
# ✓ Saved 10 pairs to fea_iterations/llm_batch_iter_0.csv for LLM processing
# ✓ LLM labeled pairs updated: 219197 total in labeled_pairs/llm_labeled_pairs.csv
# ✓ No persistent unlabeled_pairs pool — candidates generated fresh each iteration.
# ✓ Glued df_to_llm to scrapbook for FEA_Loop retrieval
#
# Iteration 0 complete
