# %%
import pandas as pd
import sys
import transformers.utils.hub
import transformers.tokenization_utils_base
import pickle
import importlib
import os
import papermill as pm
import scrapbook as sb
import numpy as np

from sentence_transformers import SentenceTransformer
from collections import defaultdict
from typing import List, Tuple, Any, Mapping, Iterable, Dict, Literal

import free_entailments_algorithm_utils as fea

# %%
iteration_number = 1
input_csv_path = "labeled_pairs/Results_DS_BtoS_iteration_0.csv"
df_clause_path = None
embedding_cache_path = None
test = True
remaining_llm_calls_path = None
unlabeled_pairs_path = None
sent_frac = 0.5
budget = 0.0

# %%
# Parameters
iteration_number = 3
input_csv_path = "fea_iterations/loop_data/accumulated_labeled_iter_2.csv"
df_clause_path = "fea_iterations/loop_data/df_clause.pkl"
embedding_cache_path = "fea_iterations/loop_data/embedding_cache.pkl"
test = True
remaining_llm_calls_path = "fea_iterations/loop_data/remaining_llm_calls.pkl"
unlabeled_pairs_path = None
sent_frac = 0.5
budget = 0.0

# %%
pipeline_data = fea.load_pipeline_data(
    df_clause_path=df_clause_path,
    embedding_cache_path=embedding_cache_path,
    test=test,
    remaining_llm_calls_path=remaining_llm_calls_path,
    unlabeled_pairs_path=unlabeled_pairs_path,
    iteration_number=iteration_number,
)

df_clause = pipeline_data['df_clause']
embedding_cache_finetuned = pipeline_data['embedding_cache']
remaining_llm_calls = pipeline_data['remaining_llm_calls']
unlabeled_pairs = pipeline_data['unlabeled_pairs']
# Out:
# ================================================================================
# PARAMETER VALUES AFTER PAPERMILL INJECTION:
# ================================================================================
# iteration_number = 3
# test = True
# remaining_llm_calls_path = fea_iterations/loop_data/remaining_llm_calls.pkl
# df_clause_path = fea_iterations/loop_data/df_clause.pkl
# ================================================================================
#
# ✓ Loaded df_clause: 63909 rows
# ✓ Loaded embedding cache: 63909 embeddings
# ✓ Loaded remaining_llm_calls: 4818 rows
# ✓ All data loaded from pickle files

# %% [markdown]
# # Task 1: Seting up dataframes and Running FEA

# %%
df_llm_original = pd.read_csv(input_csv_path)

df_llm = fea.add_verdict(
    df_llm_original,
    id1_col='sentence_id_1',
    id2_col='sentence_id_2',
    conclusion_col='llm_conclusion_12',
    positive_label='YES'
)

if test:
    df_llm_remaining = fea.add_verdict(
        remaining_llm_calls,
        id1_col='sentence_id_1',
        id2_col='sentence_id_2',
        conclusion_col='llm_conclusion_12',
        positive_label='YES'
    )
# Out:
# ======================================================================
# VERDICT SUMMARY
# ======================================================================
# Total pairs: 5182
# Bidirectional entailment (YES): 657 (12.7%)
# Not bidirectionally entailed (NO): 4525 (87.3%)
# ======================================================================
# ======================================================================
# VERDICT SUMMARY
# ======================================================================
# Total pairs: 4818
# Bidirectional entailment (YES): 558 (11.6%)
# Not bidirectionally entailed (NO): 4260 (88.4%)
# ======================================================================

# %%
df_labeled = fea.merge_pairwise_texts(
    df1 = df_clause,
    df2 = df_llm,
    df1_cols = ['sentence_id', 'sentence'],
    df2_cols = ['sentence_id_1', 'sentence_id_2', 'verdict']
)
df_labeled.head()
# Out:
#           id1            id2  \
# 0  B0860002sc  S0010771002sc
# 1  B1170001sc  S0020225001sc
# 2   B0454001p   S0004868005p
# 3  B0227001sc  S0000883002sc
# 4  B0580002sc  S0023399001sc
#
#                                                text1  \
# 0  The king's support must match his responsibili...
# 1  Active governance by the prince is essential f...
# 2  Agrarian laws can effectively prevent the rise...
# 3  Parliament should hold the power to correct le...
# 4  The king's presence is essential for validatin...
#
#                                                text2 verdict
# 0  clear evidence of acting against the interests...      NO
# 1  Maintaining respect for the monarchy is essential      NO
# 2  This situation highlights the tension between ...      NO
# 3             Parliament must uphold the rule of law     YES
# 4                   Parliament must assert authority      NO

# %%
if test:
    df_predict = fea.merge_pairwise_texts(
        df1 = df_clause,
        df2 = df_llm_remaining,
        df1_cols = ['sentence_id', 'sentence'],
        df2_cols = ['sentence_id_1', 'sentence_id_2']
    )
else:
    df_predict = fea.setminus(
        df_big= unlabeled_pairs,
        df_small= df_labeled,
        id_cols = ['id1', 'id2']
    )

    df_predict = fea.merge_pairwise_texts(
        df1 = df_clause,
        df2 = df_predict,
        df1_cols = ['sentence_id', 'sentence'],
        df2_cols = ['id1', 'id2']
    )

df_predict.head()
# Out:
#           id1            id2  \
# 0   B0783006p   S0019961006p
# 1  B1129001sc  S0003329002sc
# 2  B0287002sc  S0019015004sc
# 3  B1086002sc  S0023795002sc
# 4   B0336005p   S0016856004p
#
#                                                text1  \
# 0  The Parliament holds the power to regulate the...
# 1     A monarchical dominion needs a clear hierarchy
# 2      A government must maintain societal integrity
# 3          threatens the stability of a Commonwealth
# 4  Such focused discussions would enable the coun...
#
#                                                text2  verdict
# 0  By promptly seeking the King's guidance, Parli...      NaN
# 1    to enhance the monarchy-Parliament relationship      NaN
# 2        Accountability ensures government integrity      NaN
# 3  Preserving Parliament's authority is essential...      NaN
# 4  Established procedures should guide discussion...      NaN

# %% [markdown]
# ## Embedding All Sentences

# %%
##Patches an error later on with kwargs

def _safe_list_templates(*args, **kwargs):
    return []

transformers.utils.hub.list_repo_templates = _safe_list_templates
print(" - Patched transformers.utils.hub")

# The library had already imported the broken function here, so we must update it.
transformers.tokenization_utils_base.list_repo_templates = _safe_list_templates
print(" - Patched transformers.tokenization_utils_base")

print("\nSUCCESS: The 404 error is now blocked.")
# Out:
#  - Patched transformers.utils.hub
#  - Patched transformers.tokenization_utils_base
#
# SUCCESS: The 404 error is now blocked.

# %% [markdown]
# ## Test and Validation Subsamples

# %%
# Keep only entailed pairs from sent
df_obs_ent = df_labeled.loc[df_labeled['verdict'] == 'YES']
df_obs_ent.head()
# Out:
#            id1            id2  \
# 3   B0227001sc  S0000883002sc
# 18  B0134001sc  S0004953001sc
# 20   B0794007p   S0000823011p
# 22   B0161002p     S15310007p
# 26   B0252006p   S0000715007p
#
#                                                 text1  \
# 3   Parliament should hold the power to correct le...
# 18  Governance derives its legitimacy from the peo...
# 20  King Charles's actions demonstrate a tyrannica...
# 22  Such actions threaten the liberties and well-b...
# 26  The authority of governing bodies, like Parlia...
#
#                                                 text2 verdict
# 3              Parliament must uphold the rule of law     YES
# 18  Governance legitimacy should come from the wil...     YES
# 20  King Charles I's disregard for the people's vo...     YES
# 22  Such actions endanger the rights of individual...     YES
# 26  Parliament serves as a check on the power of t...     YES

# %%
df_candidates = fea.add_equivalents_from_pairs(
    df3=df_obs_ent,
    df4=df_predict,
    df3_cols=["id1", "id2"],
    df4_cols=["id1", "id2"],
    new_cols=("equivalents1", "equivalents2"),
    include_self=False,
)

df_candidates = fea.add_alpha_weight_column(
    df = df_candidates,
    list_col1 = 'equivalents1',
    list_col2 = 'equivalents2',
    new_col = "alpha"
)

# %%
df_labeled = fea.add_equivalents_from_pairs(
    df3=df_obs_ent,
    df4=df_labeled,
    df3_cols=["id1", "id2"],
    df4_cols=["id1", "id2"],
    new_cols=("equivalents1", "equivalents2"),
    include_self=False,  # keep the ID itself in the list
)

df_labeled = fea.add_alpha_weight_column(
    df = df_labeled,
    list_col1 = 'equivalents1',
    list_col2 = 'equivalents2',
    new_col = "alpha"
)

# %% [markdown]
# ## Equivalence Classes

# %%
# Produce set of all pairs of clauses i/j with k in the class of j/i
df_crossed = fea.build_equiv_pair_candidates(
    df = df_candidates,
    id1_col = "id1",
    id2_col = "id2",
    equiv1_col = "equivalents1",
    equiv2_col = "equivalents2",
)

# Retrieve clause sentences
df_crossed = fea.merge_pairwise_texts(
    df1 = df_clause,
    df2 = df_crossed,
    df1_cols = ['sentence_id', 'sentence'],
    df2_cols = ['id1', 'id2']
)

df_crossed.head()
# Out:
# Filtered 2195 pairs (kept 879).
#           id1         id2                                              text1  \
# 0   B0663002p   B0382007p  A king's power and authority are best confirme...
# 1   B0383006p   B0087006p  If a ruler acts as an enemy to their subjects,...
# 2   B0383006p   B0260004p  If a ruler acts as an enemy to their subjects,...
# 3  B0711002sc  B0204002sc  Laws establish a structured relationship with ...
# 4  B0711002sc  B0289001sc  Laws establish a structured relationship with ...
#
#                                                text2  verdict
# 0  The mutual obligation between the king and the...      NaN
# 1  The overarching control of a single ruler can ...      NaN
# 2  This demonstrates that authority is not an inh...      NaN
# 3  Laws protect their rights in the political str...      NaN
# 4  The legal system ensures justice through a col...      NaN

# %%
df_labeled_crossed = fea.build_equiv_pair_candidates(
    df = df_labeled,
    id1_col = "id1",
    id2_col = "id2",
    equiv1_col = "equivalents1",
    equiv2_col = "equivalents2",
)

# Retrieve clause sentences
df_labeled_crossed = fea.merge_pairwise_texts(
    df1 = df_clause,
    df2 = df_labeled_crossed,
    df1_cols = ['sentence_id', 'sentence'],
    df2_cols = ['id1', 'id2']
)

df_labeled_crossed.head()
# Out:
# Filtered 3264 pairs (kept 2427).
#           id1         id2                                              text1  \
# 0   B0454001p   B0203001p  Agrarian laws can effectively prevent the rise...
# 1   B0454001p   B0278002p  Agrarian laws can effectively prevent the rise...
# 2   B0454001p   B0314009p  Agrarian laws can effectively prevent the rise...
# 3  B0227001sc  B0227001sc  Parliament should hold the power to correct le...
# 4  B0244002sc  B0311001sc  Parliaments in England can create laws indepen...
#
#                                                text2  verdict
# 0     Laws are necessary to limit the power of kings      NaN
# 1  Allowing a King to have absolute power undermi...      NaN
# 2  The historical context shows that the struggle...      NaN
# 3  Parliament should hold the power to correct le...      NaN
# 4  The king requires parliamentary approval to im...      NaN

# %% [markdown]
# ## Running FEA

# %%
df_final, fig_html = fea.run_fea_papermill(
    iteration_number=iteration_number,
    df_candidates=df_candidates,
    df_crossed=df_crossed,
    df_labeled=df_labeled,
    df_labeled_crossed=df_labeled_crossed,
    df_obs_ent=df_obs_ent,
    df_clause=df_clause,
    embedding_cache=embedding_cache_finetuned,
)
# Out:
# Executing FreeEntailmentAlgorithm.ipynb for iteration 3...
# Executing:   0%|          | 0/33 [00:00<?, ?cell/s]
# ✓ Retrieved outputs:
#   - df_final: 30 rows
#   - fig_html: HTML plot (14844 chars)

# %%
df_final.head()
# Out:
#             id1            id2  \
# 274  B0316001sc  S0017330003sc
# 365   B0566003p   S0022913006p
# 416   B0268007p   S0017381010p
# 431   B0789007p   S0023251001p
# 556   B0380003p   S0024281008p
#
#                                                  text1  \
# 274  An absolute monarchy without the consent of th...
# 365  The essence of kingship lies in the notion tha...
# 416        The Parliament acts on behalf of the People
# 431  If the king's rule leads to oppression or unde...
# 556  The king is entrusted with governance for the ...
#
#                                                  text2  entailment_probability
# 274  The monarchy must maintain governance legitima...                0.433528
# 365  The people should not grant authority to a rul...                0.420576
# 416  Parliament must uphold the rights of its const...                0.953736
# 431  The prerogative of the King must be upheld, as...                0.883361
# 556  By engaging with Parliament, the King can ensu...                0.984057

# %% [markdown]
# # Task 2: Cleaning LLM Calls

# %%
df_final = df_final.reset_index(drop=True)
df_to_llm, rest_above_tau = fea.two_random_subsamples(df_final, sent_frac, 1 - sent_frac, 42)

# %%
df_to_llm = fea.format_df_to_llm(df_to_llm)
df_to_llm.head()
# Out:
#     sentence_id_2 sentence_id_1  \
# 29  S0000962003sc    B1131001sc
# 16     S10938004p     B0395004p
# 7   S0018785001sc    B0311001sc
# 25  S0023870002sc    B0770001sc
# 24     S10938004p     B0370005p
#
#                                       sentence_text_2 argument_id_2  \
# 29     Parliament must ensure the kingdom's stability        S00009
# 16  The King does not have any additional authorit...        S10938
# 7   A careful balance of power between the monarch...        S00187
# 25  Accountability in politics is essential for ma...        S00238
# 24  The King does not have any additional authorit...        S10938
#
#                                       sentence_text_1 argument_id_1     score
# 29  Governance should balance the king's orders wi...         B1131  0.534539
# 16  This distinction is crucial because it recogni...         B0395  0.420576
# 7   The king requires parliamentary approval to im...         B0311  0.534539
# 25      A monarchy can coexist with popular authority         B0770  0.821134
# 24  Rulers should only wield authority against tho...         B0370  0.256359

# %%
df_to_llm.shape
# Out:
# (15, 7)

# %% [markdown]
# # Next loop:

# %%
result = fea.finalize_pipeline_iteration(
    test=test,
    df_to_llm=df_to_llm,
    iteration_number=iteration_number,
    remaining_llm_calls=remaining_llm_calls,
    remaining_llm_calls_path=remaining_llm_calls_path,
    unlabeled_pairs=unlabeled_pairs,
    unlabeled_pairs_path=unlabeled_pairs_path,
)

remaining_llm_calls = result['remaining_llm_calls']
unlabeled_pairs = result['unlabeled_pairs']
# Out:
# ============================================================
# TEST MODE: Mocking LLM responses
# ============================================================
# ✓ Matched 15/15 pairs with mock LLM results
# ✓ Removed 15 pairs from remaining LLM calls
# ✓ Remaining pairs for future iterations: 4803
# ✓ Saved updated remaining_llm_calls to fea_iterations/loop_data/remaining_llm_calls.pkl
# ✓ Saved 15 pairs with LLM results to fea_iterations/llm_batch_iter_3.csv
#
# Iteration 3 complete
