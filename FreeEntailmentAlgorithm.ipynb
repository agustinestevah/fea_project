# %% [markdown]
# # Set up

# %% [markdown]
# ## Import libraries

# %%
import sys
import os
import shutil

######          RUN IF YOU ARE ON MIDWAY3 (very intensive work, sets up environment)        #######


# username = os.environ.get('USER')
# scratch_base = f"/scratch/midway3/{username}"
# custom_lib_path = os.path.join(scratch_base, "my_custom_libs")
# py_version = f"python{sys.version_info.major}.{sys.version_info.minor}"
# site_packages = os.path.join(custom_lib_path, "lib", py_version, "site-packages")

# print(f"Targeting: {site_packages}")

#
# We delete the entire library folder to ensure NO conflicting files remain.
# if os.path.exists(custom_lib_path):
#     print(f"Removing old libraries at {custom_lib_path}...")
#     try:
#         shutil.rmtree(custom_lib_path)
#         print("Cleanup complete. Folder is empty.")
#     except Exception as e:
#         print(f"Warning: Could not fully delete folder ({e}). Proceeding anyway...")
# else:
#     print("Folder was already clean.")


# install_cmd = (
#     f"pip install --target='{site_packages}' "
#     "--upgrade "
#     "--no-cache-dir "          # Force download of fresh, uncorrupted files
#     "'numpy<2.0' "              # Prevent Numpy 2.0 crashes
#     "'pandas' "
#     "'bottleneck' "             # Fixes Pandas warning
#     "'numexpr' "                # Fixes Pandas warning
#     "'torch' "                  # Install Torch in scratch
#     "'torchvision' "            # Install Torchvision in scratch (matches Torch)
#     "'accelerate>=0.31.0' "
#     "'transformers' "
#     "'sentence-transformers' "
# )

# print("\nStarting Clean Install (This may take a few minutes)...")
# exit_code = os.system(install_cmd)

# if exit_code == 0:
#     print("\nSUCCESS: Complete stack installed.")
# else:
#     print(f"\nERROR: Installation failed with code {exit_code}")

# %%
import sys
import os

# MORE MIDWAY3 PATCHES


# !pip install --target="{site_packages}" \
#     --upgrade \
#     --no-cache-dir \
#     "datasets" \
#     "botocore" \
#     "aiobotocore" \
#     "s3fs"

# print("\nPatch complete. Please Restart Kernel.")

# %%
import sys
import os

## RUN THIS IF ON MIDWAY3 TO INSTALL EXCEL SUPPORT ##

# # 1. SETUP PATHS
# username = os.environ.get('USER')
# scratch_base = f"/scratch/midway3/{username}"
# custom_lib_path = os.path.join(scratch_base, "my_custom_libs")
# py_version = f"python{sys.version_info.major}.{sys.version_info.minor}"
# site_packages = os.path.join(custom_lib_path, "lib", py_version, "site-packages")

# print(f"Installing Excel support in: {site_packages}")


# !pip install --target="{site_packages}" \
#     --upgrade \
#     --no-cache-dir \
#     "openpyxl"

# print("\nInstall complete. Please Restart Kernel.")

# %%
#### INSTALL THESE PACKAGES (might run into some issues) ####



# 
# install_cmd = (
#     f"pip install --target='{site_packages}' "
#     "--upgrade "
#     "--no-cache-dir "          # Force download of fresh, uncorrupted files
#     "'numpy<2.0' "              # Prevent Numpy 2.0 crashes
#     "'pandas' "
#     "'bottleneck' "             # Fixes Pandas warning
#     "'numexpr' "                # Fixes Pandas warning
#     "'torch' "                  # Install Torch in scratch
#     "'torchvision' "            # Install Torchvision in scratch (matches Torch)
#     "'accelerate>=0.31.0' "
#     "'transformers' "
#     "'sentence-transformers' "
# )

# !pip install sentencepiece

# !pip install --target="{site_packages}" \
#     --upgrade \
#     --no-cache-dir \
#     "datasets" \
#     "botocore" \
#     "aiobotocore" \
#     "s3fs"

# !pip install --target="{site_packages}" \
#     --upgrade \
#     --no-cache-dir \
#     "openpyxl"


##### RESTART KERNEL #####

# %%
##### FOR MIDWAY3 ####

# # --- 1. SETUP PATHS ---
# username = os.environ.get('USER')
# scratch_base = f"/scratch/midway3/{username}"
# custom_lib_path = os.path.join(scratch_base, "my_custom_libs")
# hf_cache_path = os.path.join(scratch_base, "hf_cache")

# py_version = f"python{sys.version_info.major}.{sys.version_info.minor}"
# site_packages = os.path.join(custom_lib_path, "lib", py_version, "site-packages")

# if site_packages not in sys.path:
#     sys.path.insert(0, site_packages)

# # --- 2. ENV VARIABLES ---
# os.environ['HF_HOME'] = hf_cache_path
# os.environ['TRANSFORMERS_CACHE'] = hf_cache_path
# os.environ['PYTHONUSERBASE'] = custom_lib_path

# # --- 3. THE FINAL TEST ---
# import datasets
# import sentence_transformers
# from sentence_transformers import SentenceTransformer

# print(f"Datasets Path: {os.path.dirname(datasets.__file__)}")
# # This MUST say /scratch/midway3/...

# if "software" in os.path.dirname(datasets.__file__):
#     print("FAILURE: Still loading system datasets.")
# else:
#     print("SUCCESS: All libraries isolated in scratch.")

# %%
## Run after installing packages and restarting kernel ##

import importlib
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from collections import defaultdict
from typing import List, Tuple, Any, Mapping, Iterable, Dict, Literal

import free_entailments_algorithm_utils as fea

# %%
importlib.reload(fea)

# %% [markdown]
# ## Declare paths

# %%
#Not important if you are not Rafael:
# Main
root_path = r"C:\Users\ralph\OneDrive - Universidad de los Andes\Documentos\Predoc_UChicago2024\CULTURE"

#Inputs
input_path = root_path + r"\DATA\FreeEntailmentsTest\Inputs"

#Outputs
output_path = root_path + r"\DATA\FreeEntailmentsTest\Outputs"

# %% [markdown]
# ## Import data

# %%
#Edit these files paths accordingly

df_p = pd.read_excel('/home/aesteva/Downloads/Dropbox(1)/ClauseLevel_df_p.xlsx') #premises
df_sc = pd.read_excel("/home/aesteva/Downloads/Dropbox(1)/ClauseLevel_df_sc.xlsx") #conclusions
df_llm = pd.read_csv("/home/aesteva/Downloads/Dropbox(1)/all_results (1).csv") #llm results

# %% [markdown]
# # Prepare data

# %%
# Unify clauses form premises and conclusions into a single dataframe
df_clause = pd.concat([df_p,df_sc])

# %%
# Merge clause pairs with entailment and text
df_clause_entailment = fea.merge_pairwise_texts(
    df1 = df_clause,
    df2 = df_llm,
    df1_cols = ['sentence_id', 'sentence'],
    df2_cols = ['sentence_id_1', 'sentence_id_2', 'twoway']
)

# %%
print(f"Shape: {df_clause_entailment.shape}")
df_clause_entailment.head()

# %%
df_clause_entailment_test = df_clause_entailment.sample(frac=0.1, replace=False, random_state=42)

# %%
len(df_clause_entailment_test)

# %% [markdown]
# # Compute Cosine Similarities

# %%
# PATCH FOR TRANSFORMERS 404 ERROR Found in Midway3-might be unecessary locally#

import sys
import transformers.utils.hub
import transformers.tokenization_utils_base


# This function does nothing but return an empty list, bypassing the error entirely.
def _safe_list_templates(*args, **kwargs):
    return []


# 2. Patch the Source
transformers.utils.hub.list_repo_templates = _safe_list_templates
print(" - Patched transformers.utils.hub")

# The library had already imported the broken function here, so we must update it.
transformers.tokenization_utils_base.list_repo_templates = _safe_list_templates
print(" - Patched transformers.tokenization_utils_base")

print("\nSUCCESS: The 404 error is now blocked.")

# %%
df_pairs = fea.add_cosine_similarity_from_text(
    df_clause_entailment_test,
    text_col1="text1",
    text_col2="text2",
    model_name="BAAI/bge-large-en-v1.5",
    batch_size=128,
    show_progress_bar=True
)

# %%
print(f"Shape: {df_pairs.shape}")
df_pairs.head()

# %% [markdown]
# # 'Send' to LLM

# %% [markdown]
# ## Generate subsamples: truth, test

# %%
df_labeled, df_predict = fea.two_random_subsamples(
    df = df_pairs,
    frac1 = 0.2,
    frac2 = 0.8,
    random_state = 42
)

# %%
# Keep only entailed pairs from sent
df_obs_ent = df_labeled.loc[df_labeled['verdict'] == 'YES']
df_obs_ent.head()

# %%
print(len(df_labeled),len(df_predict),len(df_obs_ent))

# %%
# Get set of pairs observed to be entailed to each clause
df_candidates = fea.add_equivalents_from_pairs(
    df3=df_obs_ent,
    df4=df_predict,
    df3_cols=["id1", "id2"],
    df4_cols=["id1", "id2"],
    new_cols=("equivalents1", "equivalents2"),
    include_self=False,  # keep the ID itself in the list
)

# %%
# Get adequate weight
df_candidates = fea.add_alpha_weight_column(
    df = df_candidates,
    list_col1 = 'equivalents1',
    list_col2 = 'equivalents2',
    new_col = "alpha"
)

# %%
df_candidates.shape

# %% [markdown]
# # Train Models On LLM Results

# %%
## RUN IF YOU ARE ON MIDWAY3 TO CLEAR GPU CACHE ##
 
# import torch
# import gc

# # 1. Force Python's garbage collector to release references
# gc.collect()

# # 2. Force PyTorch to release cached CUDA memory
# torch.cuda.empty_cache()

# print("GPU Cache Cleared.")

# %%
#ALSO NECESSARY FOR CROSS-ENCODER SHAPE MISMATCH PATCH##
## Can skip if not training models.

import sys
import os
import transformers.utils.hub
import transformers.tokenization_utils_base
from sentence_transformers import CrossEncoder


def _safe_list_templates(*args, **kwargs):
    return []

transformers.utils.hub.list_repo_templates = _safe_list_templates
transformers.tokenization_utils_base.list_repo_templates = _safe_list_templates
print("1. [Success] 404 Error blocked.")


if not hasattr(CrossEncoder, "_original_init"):
    CrossEncoder._original_init = CrossEncoder.__init__

def _patched_init(self, *args, **kwargs):
    if "model_kwargs" not in kwargs:
        kwargs["model_kwargs"] = {}
    # Force the model to ignore the size mismatch in the final layer
    kwargs["model_kwargs"]["ignore_mismatched_sizes"] = True
    # Call the original function
    CrossEncoder._original_init(self, *args, **kwargs)

CrossEncoder.__init__ = _patched_init
print("2. [Success] Shape mismatch patch applied.")


try:
    import sentencepiece
    print("3. [Success] SentencePiece is installed and detected.")
except ImportError:
    print("3. [ERROR] SentencePiece is STILL missing. Did you restart the kernel?")

print("\nREADY: You can now run your training code.")

# %%
##TRAINING-I have done this for you, no need to train models, just immport the fine-tuned models I have supplied##



# fea.train_bert_model(
#     df_train=df_labeled,
#     text_col1='text1',
#     text_col2='text2',
#     verdict_col='verdict',
#     positive_label='YES',
#     base_model_name='BAAI/bge-large-en-v1.5', # Updated to better model
#     output_path="./fine_tuned_bi_model",
#     batch_size=32, 
#     num_epochs=4
# )

# fea.train_bert_model(
#     df_train=df_labeled,
#     text_col1='text1',
#     text_col2='text2',
#     verdict_col='verdict',
#     base_model_name="cross-encoder/nli-deberta-v3-base",
#     output_path="./fine_tuned_nli_model",
#     model_type="cross-encoder", 
#     batch_size=32,
#     num_epochs=4
# )

# %%
##Adds new column to the main df for the trained cosine similarity##

df_main = fea.generate_new_bert_results(
    df_pairs,
    text_col1='text1',
    text_col2='text2',
    model_path="./fine_tuned_bi_model",
    new_col="new_cos_sim_score",
    # batch_size=128, #Can add or not depending on speed and memory
)

# %%
##Adds new column to the main df for the trained nli similarity##


df_main = fea.add_cross_encoder_score(
    df_pairs,                  
    text_col1='text1',
    text_col2='text2',
    model_name="./fine_tuned_nli_model",  
    new_col="nli_score",
    batch_size=128              
)

df_main.head()

# %%
# Extract the subsets from df_main using the indices of the original splits
# df_main contains the new BERT scores, so we want to see those scores for our train/test sets


df_labeled_with_scores = df_main.loc[df_labeled.index]

df_predict_with_scores = df_main.loc[df_predict.index]

df_obs_ent_with_scores = df_main.loc[df_obs_ent.index]

print(f"Labeled set shape: {df_labeled_with_scores.shape}")
print(f"Prediction set shape: {df_predict_with_scores.shape}")
print(f"Observed entailments shape: {df_obs_ent_with_scores.shape}")

#df_obs_ent_with_scores.head()

# %%
# Get set of pairs observed to be entailed to each clause
df_candidates_with_scores = fea.add_equivalents_from_pairs(
    df3=df_obs_ent_with_scores,
    df4=df_predict_with_scores,
    df3_cols=["id1", "id2"],
    df4_cols=["id1", "id2"],
    new_cols=("equivalents1", "equivalents2"),
    include_self=False,  # keep the ID itself in the list
)

# Get adequate weight
df_candidates_with_scores = fea.add_alpha_weight_column(
    df = df_candidates_with_scores,
    list_col1 = 'equivalents1',
    list_col2 = 'equivalents2',
    new_col = "alpha"
)

df_candidates_with_scores.head()

# %% [markdown]
# ## Building Equivalence Classes

# %%
# Produce set of all pairs of clauses i/j with k in the class of j/i
df_crossed = fea.build_equiv_pair_candidates(
    df = df_candidates_with_scores,
    id1_col = "id1",
    id2_col = "id2",
    equiv1_col = "equivalents1",
    equiv2_col = "equivalents2",
)

# %%
# Retrieve clause sentences
df_crossed = fea.merge_pairwise_texts(
    df1 = df_clause,
    df2 = df_crossed,
    df1_cols = ['sentence_id', 'sentence'],
    df2_cols = ['id1', 'id2']
)

df_crossed.head()

# %% [markdown]
# # Compute Cos Sim Neighborhood

# %%
# Produce cosine similarity scores for i/j with k in the class of j/i
df_crossed = fea.add_cosine_similarity_from_text(
    df_crossed,
    text_col1="text1",
    text_col2="text2",
    model_name="./fine_tuned_bi_model",
    batch_size=128,
    show_progress_bar=True
)

df_crossed.head()

# %% [markdown]
# # Features

# %% [markdown]
# ## Compute Cos Sim Neighborhood Score

# %%
df_candidates = fea.compute_neighbor_weighted_score(
    df5 = df_crossed,
    df6 = df_candidates_with_scores,
    id1_col = "id1",
    id2_col = "id2",
    cosim_df5_col = "cosine_sim",
    cosim_df6_col = "new_cos_sim_score",
    alpha_col = "alpha",
    eq1_col = "equivalents1",
    eq2_col = "equivalents2",
    new_col = "cos_sim_neighbor_score",
)

# %%
# keep pairs where score could be computed
df_candidates = df_candidates.loc[df_candidates['cos_sim_neighbor_score'].notna()]

df_candidates.head()

# %% [markdown]
# ## Compute NLI Score

# %%
df_crossed = fea.add_cross_encoder_score(
    df_crossed,
    text_col1="text1",
    text_col2="text2",
    
    
    model_name="./fine_tuned_nli_model", 
    batch_size=128,
    new_col="nli_score" 
)

# (add_cross_encoder_score adds the column in-place)
if "nli_score" not in df_candidates.columns:
    print("Scores added to df_crossed!")
    
df_crossed.head()

# We reuse the same function used for Cosine Similarity, but point to NLI columns.
df_candidates = fea.compute_neighbor_weighted_score(
    df5=df_crossed,
    df6=df_candidates,
    id1_col="id1",
    id2_col="id2",
    cosim_df5_col="nli_score",   
    cosim_df6_col="nli_score",   
    alpha_col="alpha",
    eq1_col="equivalents1",
    eq2_col="equivalents2",
    new_col="nli_neighbor_score"
)

cols_to_show = ['text1', 'text2', 'nli_score', 'nli_neighbor_score', 'verdict']
df_candidates[cols_to_show].head()

# %% [markdown]
# ## Compute Transitivity Score

# %%
# 'graph_entailment_score': A -> B (Path Decay applied)
# 'graph_equivalence_score': A <-> B 

df_candidates = fea.add_graph_features(
    df=df_candidates,
    entailment_df=df_obs_ent,
    id1_col="id1",
    id2_col="id2",
    verdict_col="verdict",
    positive_label="YES",
    decay=0.9,  
    max_hops=5
)

print("\nGraph Score Stats:")
print(df_candidates[['graph_entailment_score', 'graph_equivalence_score']].describe())
df_candidates.head()

# %% [markdown]
# # Predicting Entailment (can change model pipeline to something other than logistic)

# %%
features = [
    'cos_sim_neighbor_score', 
    'nli_neighbor_score', 
    'graph_entailment_score', 
    'graph_equivalence_score'
]
target = 'verdict'
positive_label = 'YES'

# (Optional) Run Hyperparameter Optimization with Optuna
try:
    print(">>> Optimizing Boosting Hyperparameters with Optuna...")
    # This might take a minute!
    best_params = fea.optimize_boosting_hyperparameters(
        df=df_candidates,
        feature_cols=features,
        target_col=target,
        positive_label=positive_label,
        n_trials=30 
    )
    
    # Add monotonic constraint assumption
    if best_params:
        best_params['enforce_monotonicity'] = True 
        
except Exception as e:
    print(f"\nOptimization skipped or failed: {e}")
    print("Using conservative defaults.")
    best_params = {
        'learning_rate': 0.05,
        'max_iter': 300,
        'enforce_monotonicity': True
    }



comparison_df, best_model_name = fea.compare_entailment_models(
    df=df_candidates,
    feature_cols=features,
    target_col=target,
    model_names=["logistic", "spline", "kernel", "tree", "boosting"], 
    positive_label=positive_label,
    **best_params 
)

# --- Display Results ---
print("\nComparison Results (Sorted by ROC-AUC):")
display(comparison_df)

print(f"\n>>> Selected '{best_model_name}' model for downstream processing.")

# %%
print(f"Retraining '{best_model_name}' with optimized parameters...")

# Note: if best_model_name is NOT 'boosting', best_params passed as kwargs 
# might be ignored or cause warnings, but sklearn usually handles kwargs
# To be safe, we only pass them if boosting is selected, or let the wrapper handle it.

best_pipeline = fea.train_entailment_model(
    df=df_candidates,
    feature_cols=features,
    target_col=target,
    method=best_model_name,
    positive_label=positive_label,
    **best_params
)

df_candidates = fea.predict_entailment_probabilities(
    df_candidates,
    model_pipeline=best_pipeline,
    feature_cols=features,
    new_col='entailment_probability'
)

df_candidates.head()

# %% [markdown]
# # Optimize threshold

# %%
# We use the generic 'entailment_probability' column which now holds the best model's output
results = fea.find_best_thresholds(df=df_candidates,
                               score_col="entailment_probability",
                               verdict_col="verdict",
                               positive_label="YES")

# %%
print("Best tau (accuracy):", results["best_tau_accuracy"],
      "Accuracy:", results["best_accuracy"])

print("Best tau (F1):", results["best_tau_f1"],
      "F1:", results["best_f1"])

print("Best tau (TP):", results["best_tau_tp"],
      "TP:", results["max_true_positives"])

print("Best tau (precision):", results["best_tau_precision"],
      "prec:", results["best_precision"])

print("Best tau (recall):",    results["best_tau_recall"],
      "rec:",  results["best_recall"])

# %%
results["best_taus_table"]

# %%
import importlib
importlib.reload(fea) 

results = fea.find_best_thresholds(
    df=df_candidates,
    score_col="entailment_probability", # Using the generic column from the best model
    verdict_col="verdict",
    positive_label="YES"
)

print("\nLow-Send Optimization (1-5% Target):")
print(f"Selected Low-Send Threshold: {results['best_tau_low_send']:.6f}")
display(results["low_send_table"])

print("\n>>> Interactive Analysis: LLM Savings vs Threshold")

markers_to_show = {
    "Optimization": results["best_tau_low_send"],
    "Max Accuracy": results["best_tau_accuracy"],
    "Max F1":       results["best_tau_f1"],
}

fea.plot_llm_savings_over_thresholds(
    df=df_candidates,
    prob_col="entailment_probability",
    verdict_col="verdict",
    positive_label="YES",
    step=0.01,
    markers=markers_to_show
)
